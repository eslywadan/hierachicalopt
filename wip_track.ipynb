# %% [markdown]
# # WIP Tracking System - Quick Introduction
#
# ## What is WIP Tracking?
#
# WIP (Work In Progress) tracking monitors products as they move through manufacturing stages, from raw materials to finished goods. It provides real-time visibility into production status, bottlenecks, and quality metrics.
#
# ## Core Features
#
# ### 1. **Real-Time Lot Tracking**
# - Track each production lot with unique identifiers (e.g., LOT-001)
# - Monitor current location, status, and quantities
# - Link lots to work orders and customer orders
#
# ### 2. **Event History Recording**
# - Capture every production event (start, complete, inspection, move)
# - Record timestamps, operators, equipment, and outcomes
# - Maintain complete audit trail for traceability
#
# ### 3. **Status Management**
# - Queue → In Process → Completed → Inspection → Move
# - Track good quantity, scrap, and rework
# - Monitor cycle times and queue times
#
# ### 4. **Analytics & Reporting**
# - Bottleneck identification
# - Yield analysis and first-pass quality rates
# - Operator and equipment performance metrics
# - Predictive analytics for maintenance scheduling
#
# ## Basic Usage
#
# ### Setup
# ```python
# from manufacturing.wip_track import WIPTracker, WIPAnalytics
#
# # Initialize
# tracker = WIPTracker()
# analytics = WIPAnalytics()
# ```
#
# ### Core Operations
#
# **1. Start Production:**
# ```python
# tracker.start_operation(session, "LOT-001", operator_id="OP001")
# ```
#
# **2. Complete Operation:**
# ```python
# tracker.complete_operation(session, "LOT-001",
#                          good_qty=95, scrap_qty=5)
# ```
#
# **3. Quality Inspection:**
# ```python
# tracker.record_quality_check(session, "LOT-001",
#                             passed=True, measurements={...})
# ```
#
# **4. Move Between Operations:**
# ```python
# tracker.move_to_next_operation(session, "LOT-001",
#                               next_operation_id=2)
# ```
#
# ### Query Examples
#
# **Check Lot Status:**
# ```python
# timeline = analytics.get_lot_timeline(session, "LOT-001")
# ```
#
# **Find Bottlenecks:**
# ```sql
# SELECT operation_code, AVG(queue_time_minutes) as avg_wait
# FROM wip_history
# WHERE event_type = 'queue_entry'
# GROUP BY operation_code
# ORDER BY avg_wait DESC;
# ```
#
# **Track Work Order Progress:**
# ```python
# summary = get_work_order_lot_summary(session, "WO-2024-001")
# # Returns: completion %, lot locations, quantities
# ```
#
# ## Key Benefits
#
# - **Visibility**: Know where every lot is at any moment
# - **Traceability**: Complete history for quality/compliance
# - **Efficiency**: Identify and resolve bottlenecks quickly
# - **Quality**: Track defects back to source operations
# - **Predictive**: Forecast completion times and maintenance needs
#
# ## Common Use Cases
#
# 1. **Production Manager**: Monitor real-time production status
# 2. **Quality Control**: Trace defects to root causes
# 3. **Planning**: Schedule based on actual cycle times
# 4. **Customer Service**: Provide accurate delivery estimates
# 5. **Continuous Improvement**: Analyze historical data for optimization
#
# The system integrates with existing MES/ERP systems and supports RFID/barcode scanning for automated data capture.

# %%
from manufacturing.wip_track  import WIPTracker, WIPAnalytics

# Initialize
tracker = WIPTracker()
analytics = WIPAnalytics()

# %%
from manufacturing.wip_track import *
# Out:
# Database 'manufacturing' already exists.

# %%
from manufacturing.datamodel import create_database, get_session
engine = create_database('postgresql://myuser:mypassword@localhost:5433/manufacturing')
session = get_session(engine)
# Out:
# 2025-09-03 11:02:17,063 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-09-03 11:02:17,065 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-03 11:02:17,073 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-09-03 11:02:17,074 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-03 11:02:17,078 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-09-03 11:02:17,079 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-03 11:02:17,084 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-03 11:02:17,090 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,091 INFO sqlalchemy.engine.Engine [generated in 0.00106s] {'table_name': 'operation_equipment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,101 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,101 INFO sqlalchemy.engine.Engine [cached since 0.01171s ago] {'table_name': 'operation_material', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,106 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,106 INFO sqlalchemy.engine.Engine [cached since 0.01627s ago] {'table_name': 'operation_substitution', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,109 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,109 INFO sqlalchemy.engine.Engine [cached since 0.01942s ago] {'table_name': 'equipment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,111 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,112 INFO sqlalchemy.engine.Engine [cached since 0.02194s ago] {'table_name': 'products', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,115 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,115 INFO sqlalchemy.engine.Engine [cached since 0.0257s ago] {'table_name': 'routes', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,119 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,119 INFO sqlalchemy.engine.Engine [cached since 0.02967s ago] {'table_name': 'sequences', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,122 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,122 INFO sqlalchemy.engine.Engine [cached since 0.03243s ago] {'table_name': 'operations', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,125 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,125 INFO sqlalchemy.engine.Engine [cached since 0.0354s ago] {'table_name': 'materials', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,128 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,128 INFO sqlalchemy.engine.Engine [cached since 0.03841s ago] {'table_name': 'bom_items', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,137 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,137 INFO sqlalchemy.engine.Engine [cached since 0.04755s ago] {'table_name': 'work_orders', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,142 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,143 INFO sqlalchemy.engine.Engine [cached since 0.05338s ago] {'table_name': 'wip_records', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,146 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,147 INFO sqlalchemy.engine.Engine [cached since 0.0573s ago] {'table_name': 'material_inventory', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,152 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,153 INFO sqlalchemy.engine.Engine [cached since 0.0631s ago] {'table_name': 'wip_history', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,156 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,157 INFO sqlalchemy.engine.Engine [cached since 0.06692s ago] {'table_name': 'wip_snapshots', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,160 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace
# WHERE pg_catalog.pg_type.typname = %(typname_1)s AND pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,160 INFO sqlalchemy.engine.Engine [generated in 0.00054s] {'typname_1': 'materialtype', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,163 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace
# WHERE pg_catalog.pg_type.typname = %(typname_1)s AND pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,164 INFO sqlalchemy.engine.Engine [cached since 0.003808s ago] {'typname_1': 'equipmentstatus', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,168 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace
# WHERE pg_catalog.pg_type.typname = %(typname_1)s AND pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,168 INFO sqlalchemy.engine.Engine [cached since 0.008378s ago] {'typname_1': 'unitofmeasure', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,172 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace
# WHERE pg_catalog.pg_type.typname = %(typname_1)s AND pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,172 INFO sqlalchemy.engine.Engine [cached since 0.01256s ago] {'typname_1': 'operationstatus', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,176 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace
# WHERE pg_catalog.pg_type.typname = %(typname_1)s AND pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,177 INFO sqlalchemy.engine.Engine [cached since 0.01693s ago] {'typname_1': 'workorderstatus', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,180 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace
# WHERE pg_catalog.pg_type.typname = %(typname_1)s AND pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 11:02:17,180 INFO sqlalchemy.engine.Engine [cached since 0.02002s ago] {'typname_1': 'wipstatus', 'nspname_1': 'pg_catalog'}
# 2025-09-03 11:02:17,183 INFO sqlalchemy.engine.Engine COMMIT

# %%
    
# Generate sample history data
generate_realistic_wip_history(session, num_work_orders=5, lots_per_order=3)
# Out:
# 2025-09-03 10:59:30,974 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-09-03 10:59:30,975 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-03 10:59:30,981 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-09-03 10:59:30,981 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-03 10:59:30,986 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-09-03 10:59:30,987 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-03 10:59:30,990 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-03 10:59:30,994 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:30,995 INFO sqlalchemy.engine.Engine [generated in 0.00061s] {'table_name': 'operation_equipment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,009 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,009 INFO sqlalchemy.engine.Engine [cached since 0.01499s ago] {'table_name': 'operation_material', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,011 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,011 INFO sqlalchemy.engine.Engine [cached since 0.01737s ago] {'table_name': 'operation_substitution', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,013 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,013 INFO sqlalchemy.engine.Engine [cached since 0.01945s ago] {'table_name': 'equipment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,017 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,017 INFO sqlalchemy.engine.Engine [cached since 0.02342s ago] {'table_name': 'products', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,019 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,020 INFO sqlalchemy.engine.Engine [cached since 0.02574s ago] {'table_name': 'routes', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,022 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,022 INFO sqlalchemy.engine.Engine [cached since 0.02839s ago] {'table_name': 'sequences', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,025 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,025 INFO sqlalchemy.engine.Engine [cached since 0.03099s ago] {'table_name': 'operations', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,027 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,027 INFO sqlalchemy.engine.Engine [cached since 0.03295s ago] {'table_name': 'materials', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,029 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,029 INFO sqlalchemy.engine.Engine [cached since 0.03492s ago] {'table_name': 'bom_items', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,031 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,031 INFO sqlalchemy.engine.Engine [cached since 0.03721s ago] {'table_name': 'work_orders', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,048 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,050 INFO sqlalchemy.engine.Engine [cached since 0.05632s ago] {'table_name': 'wip_records', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,055 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,056 INFO sqlalchemy.engine.Engine [cached since 0.0616s ago] {'table_name': 'material_inventory', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,058 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,059 INFO sqlalchemy.engine.Engine [cached since 0.06477s ago] {'table_name': 'wip_history', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,061 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,062 INFO sqlalchemy.engine.Engine [cached since 0.06763s ago] {'table_name': 'wip_snapshots', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,067 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace
# WHERE pg_catalog.pg_type.typname = %(typname_1)s AND pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,068 INFO sqlalchemy.engine.Engine [generated in 0.00080s] {'typname_1': 'materialtype', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,072 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace
# WHERE pg_catalog.pg_type.typname = %(typname_1)s AND pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,073 INFO sqlalchemy.engine.Engine [cached since 0.006074s ago] {'typname_1': 'equipmentstatus', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,079 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace
# WHERE pg_catalog.pg_type.typname = %(typname_1)s AND pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,080 INFO sqlalchemy.engine.Engine [cached since 0.01295s ago] {'typname_1': 'unitofmeasure', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,086 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace
# WHERE pg_catalog.pg_type.typname = %(typname_1)s AND pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,086 INFO sqlalchemy.engine.Engine [cached since 0.01941s ago] {'typname_1': 'operationstatus', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,090 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace
# WHERE pg_catalog.pg_type.typname = %(typname_1)s AND pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,090 INFO sqlalchemy.engine.Engine [cached since 0.02339s ago] {'typname_1': 'workorderstatus', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,094 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace
# WHERE pg_catalog.pg_type.typname = %(typname_1)s AND pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-03 10:59:31,094 INFO sqlalchemy.engine.Engine [cached since 0.0275s ago] {'typname_1': 'wipstatus', 'nspname_1': 'pg_catalog'}
# 2025-09-03 10:59:31,109 INFO sqlalchemy.engine.Engine COMMIT
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 session = get_session(engine)
#       5 # Generate sample history data
# ----> 6 generate_realistic_wip_history(session, num_work_orders=5, lots_per_order=3)
#
# NameError: name 'generate_realistic_wip_history' is not defined

# %%
wip_lot_number = "LOT-001"
wip = session.query(WIPRecord).filter_by(wip_lot_number=wip_lot_number).first()
print(wip.created_at)
print(wip.current_operation)
print(wip.current_equipment_id)
print(wip.wip_lot_number)
# Out:
# 2025-09-03 09:53:14,448 INFO sqlalchemy.engine.Engine SELECT wip_records.id AS wip_records_id, wip_records.wip_lot_number AS wip_records_wip_lot_number, wip_records.work_order_id AS wip_records_work_order_id, wip_records.current_operation_id AS wip_records_current_operation_id, wip_records.current_equipment_id AS wip_records_current_equipment_id, wip_records.quantity AS wip_records_quantity, wip_records.good_quantity AS wip_records_good_quantity, wip_records.scrap_quantity AS wip_records_scrap_quantity, wip_records.rework_quantity AS wip_records_rework_quantity, wip_records.status AS wip_records_status, wip_records.queue_entry_time AS wip_records_queue_entry_time, wip_records.process_start_time AS wip_records_process_start_time, wip_records.process_end_time AS wip_records_process_end_time, wip_records.plant AS wip_records_plant, wip_records.work_center AS wip_records_work_center, wip_records.storage_location AS wip_records_storage_location, wip_records.batch_number AS wip_records_batch_number, wip_records.serial_numbers AS wip_records_serial_numbers, wip_records.created_at AS wip_records_created_at, wip_records.updated_at AS wip_records_updated_at
# FROM wip_records
# WHERE wip_records.wip_lot_number = %(wip_lot_number_1)s
#  LIMIT %(param_1)s
# 2025-09-03 09:53:14,450 INFO sqlalchemy.engine.Engine [cached since 5128s ago] {'wip_lot_number_1': 'LOT-001', 'param_1': 1}
# 2025-09-02 02:46:11.337792
# <Operation OP-002: CNC Polishing>
# 1
# LOT-001

# %%
 # Example: Track a lot through operations
tracker = WIPTracker()
    
# Start an operation
tracker.start_operation(session, "LOT-001", operator_id="OP001", terminal_id="TERM-01")
# Out:
# 2025-09-02 16:54:17,410 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-02 16:54:17,420 INFO sqlalchemy.engine.Engine SELECT wip_records.id AS wip_records_id, wip_records.wip_lot_number AS wip_records_wip_lot_number, wip_records.work_order_id AS wip_records_work_order_id, wip_records.current_operation_id AS wip_records_current_operation_id, wip_records.current_equipment_id AS wip_records_current_equipment_id, wip_records.quantity AS wip_records_quantity, wip_records.good_quantity AS wip_records_good_quantity, wip_records.scrap_quantity AS wip_records_scrap_quantity, wip_records.rework_quantity AS wip_records_rework_quantity, wip_records.status AS wip_records_status, wip_records.queue_entry_time AS wip_records_queue_entry_time, wip_records.process_start_time AS wip_records_process_start_time, wip_records.process_end_time AS wip_records_process_end_time, wip_records.plant AS wip_records_plant, wip_records.work_center AS wip_records_work_center, wip_records.storage_location AS wip_records_storage_location, wip_records.batch_number AS wip_records_batch_number, wip_records.serial_numbers AS wip_records_serial_numbers, wip_records.created_at AS wip_records_created_at, wip_records.updated_at AS wip_records_updated_at
# FROM wip_records
# WHERE wip_records.wip_lot_number = %(wip_lot_number_1)s
#  LIMIT %(param_1)s
# 2025-09-02 16:54:17,420 INFO sqlalchemy.engine.Engine [generated in 0.00184s] {'wip_lot_number_1': 'LOT-001', 'param_1': 1}
# 2025-09-02 16:54:17,479 INFO sqlalchemy.engine.Engine UPDATE wip_records SET process_start_time=%(process_start_time)s, updated_at=%(updated_at)s WHERE wip_records.id = %(wip_records_id)s
# 2025-09-02 16:54:17,481 INFO sqlalchemy.engine.Engine [generated in 0.00206s] {'process_start_time': datetime.datetime(2025, 9, 2, 8, 54, 17, 476698), 'updated_at': datetime.datetime(2025, 9, 2, 8, 54, 17, 479703), 'wip_records_id': 1}
# 2025-09-02 16:54:17,526 INFO sqlalchemy.engine.Engine SELECT work_orders.id AS work_orders_id, work_orders.work_order_number AS work_orders_work_order_number, work_orders.product_id AS work_orders_product_id, work_orders.route_id AS work_orders_route_id, work_orders.order_quantity AS work_orders_order_quantity, work_orders.completed_quantity AS work_orders_completed_quantity, work_orders.scrapped_quantity AS work_orders_scrapped_quantity, work_orders.priority AS work_orders_priority, work_orders.planned_start_date AS work_orders_planned_start_date, work_orders.planned_end_date AS work_orders_planned_end_date, work_orders.actual_start_date AS work_orders_actual_start_date, work_orders.actual_end_date AS work_orders_actual_end_date, work_orders.due_date AS work_orders_due_date, work_orders.status AS work_orders_status, work_orders.parent_work_order_id AS work_orders_parent_work_order_id, work_orders.sales_order_number AS work_orders_sales_order_number, work_orders.customer_name AS work_orders_customer_name, work_orders.estimated_cost AS work_orders_estimated_cost, work_orders.actual_cost AS work_orders_actual_cost, work_orders.notes AS work_orders_notes, work_orders.created_by AS work_orders_created_by, work_orders.released_by AS work_orders_released_by, work_orders.created_at AS work_orders_created_at, work_orders.updated_at AS work_orders_updated_at
# FROM work_orders
# WHERE work_orders.id = %(pk_1)s
# 2025-09-02 16:54:17,527 INFO sqlalchemy.engine.Engine [generated in 0.00165s] {'pk_1': 1}
# 2025-09-02 16:54:17,538 INFO sqlalchemy.engine.Engine SELECT operations.id AS operations_id, operations.operation_number AS operations_operation_number, operations.operation_code AS operations_operation_code, operations.name AS operations_name, operations.description AS operations_description, operations.operation_type AS operations_operation_type, operations.status AS operations_status, operations.setup_time_minutes AS operations_setup_time_minutes, operations.cycle_time_minutes AS operations_cycle_time_minutes, operations.labor_time_minutes AS operations_labor_time_minutes, operations.machine_time_minutes AS operations_machine_time_minutes, operations.operators_required AS operations_operators_required, operations.skill_level_required AS operations_skill_level_required, operations.inspection_required AS operations_inspection_required, operations.inspection_frequency AS operations_inspection_frequency, operations.scrap_rate AS operations_scrap_rate, operations.rework_rate AS operations_rework_rate, operations.work_instructions AS operations_work_instructions, operations.setup_instructions AS operations_setup_instructions, operations.quality_instructions AS operations_quality_instructions, operations.sequence_id AS operations_sequence_id, operations.created_at AS operations_created_at, operations.updated_at AS operations_updated_at
# FROM operations
# WHERE operations.id = %(pk_1)s
# 2025-09-02 16:54:17,539 INFO sqlalchemy.engine.Engine [generated in 0.00131s] {'pk_1': 1}
# 2025-09-02 16:54:17,548 INFO sqlalchemy.engine.Engine SELECT equipment.id AS equipment_id, equipment.code AS equipment_code, equipment.name AS equipment_name, equipment.description AS equipment_description, equipment.equipment_group AS equipment_equipment_group, equipment.capacity_per_hour AS equipment_capacity_per_hour, equipment.efficiency AS equipment_efficiency, equipment.oee_target AS equipment_oee_target, equipment.status AS equipment_status, equipment.last_maintenance_date AS equipment_last_maintenance_date, equipment.next_maintenance_date AS equipment_next_maintenance_date, equipment.mtbf_hours AS equipment_mtbf_hours, equipment.mttr_hours AS equipment_mttr_hours, equipment.plant AS equipment_plant, equipment.department AS equipment_department, equipment.work_center AS equipment_work_center, equipment.created_at AS equipment_created_at, equipment.updated_at AS equipment_updated_at
# FROM equipment
# WHERE equipment.id = %(pk_1)s
# 2025-09-02 16:54:17,548 INFO sqlalchemy.engine.Engine [generated in 0.00069s] {'pk_1': 1}
# 2025-09-02 16:54:17,579 INFO sqlalchemy.engine.Engine INSERT INTO wip_history (wip_record_id, wip_lot_number, work_order_number, event_type, event_timestamp, operation_id, operation_code, equipment_id, equipment_code, plant, work_center, quantity, good_quantity, scrap_quantity, rework_quantity, previous_status, new_status, cycle_time_minutes, setup_time_minutes, queue_time_minutes, move_time_minutes, operator_id, operator_name, shift, quality_check_result, defect_codes, measurement_data, notes, reason_code, created_by, terminal_id) VALUES (%(wip_record_id)s, %(wip_lot_number)s, %(work_order_number)s, %(event_type)s, %(event_timestamp)s, %(operation_id)s, %(operation_code)s, %(equipment_id)s, %(equipment_code)s, %(plant)s, %(work_center)s, %(quantity)s, %(good_quantity)s, %(scrap_quantity)s, %(rework_quantity)s, %(previous_status)s, %(new_status)s, %(cycle_time_minutes)s, %(setup_time_minutes)s, %(queue_time_minutes)s, %(move_time_minutes)s, %(operator_id)s, %(operator_name)s, %(shift)s, %(quality_check_result)s, %(defect_codes)s::JSON, %(measurement_data)s::JSON, %(notes)s, %(reason_code)s, %(created_by)s, %(terminal_id)s) RETURNING wip_history.id
# 2025-09-02 16:54:17,579 INFO sqlalchemy.engine.Engine [generated in 0.00067s] {'wip_record_id': 1, 'wip_lot_number': 'LOT-001', 'work_order_number': 'WO-2024-001', 'event_type': 'process_start', 'event_timestamp': datetime.datetime(2025, 9, 2, 8, 54, 17, 476698), 'operation_id': 1, 'operation_code': 'OP-001', 'equipment_id': 1, 'equipment_code': 'CNC-001', 'plant': 'Plant 1', 'work_center': 'WC-001', 'quantity': Decimal('50.00'), 'good_quantity': None, 'scrap_quantity': Decimal('0.00'), 'rework_quantity': Decimal('0.00'), 'previous_status': 'in_process', 'new_status': 'in_process', 'cycle_time_minutes': None, 'setup_time_minutes': None, 'queue_time_minutes': None, 'move_time_minutes': None, 'operator_id': 'OP001', 'operator_name': None, 'shift': None, 'quality_check_result': None, 'defect_codes': 'null', 'measurement_data': 'null', 'notes': None, 'reason_code': None, 'created_by': 'system', 'terminal_id': 'TERM-01'}
# 2025-09-02 16:54:17,590 INFO sqlalchemy.engine.Engine COMMIT
# True

# %%
# Complete the operation
tracker.complete_operation(session, "LOT-001", good_qty=45, scrap_qty=5, 
                              defect_codes=['SCRATCH'], operator_id="OP001")
# Out:
# 2025-09-03 09:44:13,076 INFO sqlalchemy.engine.Engine SELECT wip_records.id AS wip_records_id, wip_records.wip_lot_number AS wip_records_wip_lot_number, wip_records.work_order_id AS wip_records_work_order_id, wip_records.current_operation_id AS wip_records_current_operation_id, wip_records.current_equipment_id AS wip_records_current_equipment_id, wip_records.quantity AS wip_records_quantity, wip_records.good_quantity AS wip_records_good_quantity, wip_records.scrap_quantity AS wip_records_scrap_quantity, wip_records.rework_quantity AS wip_records_rework_quantity, wip_records.status AS wip_records_status, wip_records.queue_entry_time AS wip_records_queue_entry_time, wip_records.process_start_time AS wip_records_process_start_time, wip_records.process_end_time AS wip_records_process_end_time, wip_records.plant AS wip_records_plant, wip_records.work_center AS wip_records_work_center, wip_records.storage_location AS wip_records_storage_location, wip_records.batch_number AS wip_records_batch_number, wip_records.serial_numbers AS wip_records_serial_numbers, wip_records.created_at AS wip_records_created_at, wip_records.updated_at AS wip_records_updated_at
# FROM wip_records
# WHERE wip_records.wip_lot_number = %(wip_lot_number_1)s
#  LIMIT %(param_1)s
# 2025-09-03 09:44:13,078 INFO sqlalchemy.engine.Engine [cached since 4587s ago] {'wip_lot_number_1': 'LOT-001', 'param_1': 1}
# 2025-09-03 09:44:13,159 INFO sqlalchemy.engine.Engine UPDATE wip_records SET good_quantity=%(good_quantity)s, scrap_quantity=%(scrap_quantity)s, status=%(status)s, process_end_time=%(process_end_time)s, updated_at=%(updated_at)s WHERE wip_records.id = %(wip_records_id)s
# 2025-09-03 09:44:13,161 INFO sqlalchemy.engine.Engine [cached since 4571s ago] {'good_quantity': 45, 'scrap_quantity': Decimal('10.00'), 'status': 'COMPLETED', 'process_end_time': datetime.datetime(2025, 9, 3, 1, 44, 13, 134818), 'updated_at': datetime.datetime(2025, 9, 3, 1, 44, 13, 159027), 'wip_records_id': 1}
# 2025-09-03 09:44:13,177 INFO sqlalchemy.engine.Engine SELECT work_orders.id AS work_orders_id, work_orders.work_order_number AS work_orders_work_order_number, work_orders.product_id AS work_orders_product_id, work_orders.route_id AS work_orders_route_id, work_orders.order_quantity AS work_orders_order_quantity, work_orders.completed_quantity AS work_orders_completed_quantity, work_orders.scrapped_quantity AS work_orders_scrapped_quantity, work_orders.priority AS work_orders_priority, work_orders.planned_start_date AS work_orders_planned_start_date, work_orders.planned_end_date AS work_orders_planned_end_date, work_orders.actual_start_date AS work_orders_actual_start_date, work_orders.actual_end_date AS work_orders_actual_end_date, work_orders.due_date AS work_orders_due_date, work_orders.status AS work_orders_status, work_orders.parent_work_order_id AS work_orders_parent_work_order_id, work_orders.sales_order_number AS work_orders_sales_order_number, work_orders.customer_name AS work_orders_customer_name, work_orders.estimated_cost AS work_orders_estimated_cost, work_orders.actual_cost AS work_orders_actual_cost, work_orders.notes AS work_orders_notes, work_orders.created_by AS work_orders_created_by, work_orders.released_by AS work_orders_released_by, work_orders.created_at AS work_orders_created_at, work_orders.updated_at AS work_orders_updated_at
# FROM work_orders
# WHERE work_orders.id = %(pk_1)s
# 2025-09-03 09:44:13,178 INFO sqlalchemy.engine.Engine [cached since 4587s ago] {'pk_1': 1}
# 2025-09-03 09:44:13,183 INFO sqlalchemy.engine.Engine SELECT operations.id AS operations_id, operations.operation_number AS operations_operation_number, operations.operation_code AS operations_operation_code, operations.name AS operations_name, operations.description AS operations_description, operations.operation_type AS operations_operation_type, operations.status AS operations_status, operations.setup_time_minutes AS operations_setup_time_minutes, operations.cycle_time_minutes AS operations_cycle_time_minutes, operations.labor_time_minutes AS operations_labor_time_minutes, operations.machine_time_minutes AS operations_machine_time_minutes, operations.operators_required AS operations_operators_required, operations.skill_level_required AS operations_skill_level_required, operations.inspection_required AS operations_inspection_required, operations.inspection_frequency AS operations_inspection_frequency, operations.scrap_rate AS operations_scrap_rate, operations.rework_rate AS operations_rework_rate, operations.work_instructions AS operations_work_instructions, operations.setup_instructions AS operations_setup_instructions, operations.quality_instructions AS operations_quality_instructions, operations.sequence_id AS operations_sequence_id, operations.created_at AS operations_created_at, operations.updated_at AS operations_updated_at
# FROM operations
# WHERE operations.id = %(pk_1)s
# 2025-09-03 09:44:13,184 INFO sqlalchemy.engine.Engine [cached since 4587s ago] {'pk_1': 2}
# 2025-09-03 09:44:13,191 INFO sqlalchemy.engine.Engine SELECT equipment.id AS equipment_id, equipment.code AS equipment_code, equipment.name AS equipment_name, equipment.description AS equipment_description, equipment.equipment_group AS equipment_equipment_group, equipment.capacity_per_hour AS equipment_capacity_per_hour, equipment.efficiency AS equipment_efficiency, equipment.oee_target AS equipment_oee_target, equipment.status AS equipment_status, equipment.last_maintenance_date AS equipment_last_maintenance_date, equipment.next_maintenance_date AS equipment_next_maintenance_date, equipment.mtbf_hours AS equipment_mtbf_hours, equipment.mttr_hours AS equipment_mttr_hours, equipment.plant AS equipment_plant, equipment.department AS equipment_department, equipment.work_center AS equipment_work_center, equipment.created_at AS equipment_created_at, equipment.updated_at AS equipment_updated_at
# FROM equipment
# WHERE equipment.id = %(pk_1)s
# 2025-09-03 09:44:13,192 INFO sqlalchemy.engine.Engine [cached since 4587s ago] {'pk_1': 1}
# 2025-09-03 09:44:13,197 INFO sqlalchemy.engine.Engine INSERT INTO wip_history (wip_record_id, wip_lot_number, work_order_number, event_type, event_timestamp, operation_id, operation_code, equipment_id, equipment_code, plant, work_center, quantity, good_quantity, scrap_quantity, rework_quantity, previous_status, new_status, cycle_time_minutes, setup_time_minutes, queue_time_minutes, move_time_minutes, operator_id, operator_name, shift, quality_check_result, defect_codes, measurement_data, notes, reason_code, created_by, terminal_id) VALUES (%(wip_record_id)s, %(wip_lot_number)s, %(work_order_number)s, %(event_type)s, %(event_timestamp)s, %(operation_id)s, %(operation_code)s, %(equipment_id)s, %(equipment_code)s, %(plant)s, %(work_center)s, %(quantity)s, %(good_quantity)s, %(scrap_quantity)s, %(rework_quantity)s, %(previous_status)s, %(new_status)s, %(cycle_time_minutes)s, %(setup_time_minutes)s, %(queue_time_minutes)s, %(move_time_minutes)s, %(operator_id)s, %(operator_name)s, %(shift)s, %(quality_check_result)s, %(defect_codes)s::JSON, %(measurement_data)s::JSON, %(notes)s, %(reason_code)s, %(created_by)s, %(terminal_id)s) RETURNING wip_history.id
# 2025-09-03 09:44:13,197 INFO sqlalchemy.engine.Engine [cached since 4587s ago] {'wip_record_id': 1, 'wip_lot_number': 'LOT-001', 'work_order_number': 'WO-2024-001', 'event_type': 'process_complete', 'event_timestamp': datetime.datetime(2025, 9, 3, 1, 44, 13, 134818), 'operation_id': 2, 'operation_code': 'OP-002', 'equipment_id': 1, 'equipment_code': 'CNC-001', 'plant': 'Plant 1', 'work_center': 'WC-001', 'quantity': Decimal('50.00'), 'good_quantity': 45, 'scrap_quantity': Decimal('10.00'), 'rework_quantity': Decimal('0.00'), 'previous_status': 'queue', 'new_status': 'completed', 'cycle_time_minutes': None, 'setup_time_minutes': None, 'queue_time_minutes': None, 'move_time_minutes': None, 'operator_id': 'OP001', 'operator_name': None, 'shift': None, 'quality_check_result': None, 'defect_codes': '["SCRATCH"]', 'measurement_data': 'null', 'notes': None, 'reason_code': None, 'created_by': 'system', 'terminal_id': None}
# 2025-09-03 09:44:13,225 INFO sqlalchemy.engine.Engine COMMIT
# True

# %%
from manufacturing.datamodel import Operation, Sequence, Route
# Create Sequence
sequence = Sequence(
        sequence_number=20,
        name="Polishing Sequence",
        route_id=1,
        setup_time=30,
        cycle_time=120
    )
operation = Operation(
        operation_number=20,
        operation_code="OP-002",
        name="CNC Polishing",
        sequence=sequence,
        operation_type="polishing",
        setup_time_minutes=30,
        cycle_time_minutes=20,
        operators_required=1
    )
session = get_session(engine)
#session.add(sequence)
#session.add(operation)
#session.commit()

# %%
# Move to next operation
session = get_session(engine)
tracker.move_to_next_operation(session, "LOT-001", next_operation_id=2, move_time_minutes=15)
# Out:
# 2025-09-03 09:12:08,852 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-03 09:12:08,858 INFO sqlalchemy.engine.Engine SELECT wip_records.id AS wip_records_id, wip_records.wip_lot_number AS wip_records_wip_lot_number, wip_records.work_order_id AS wip_records_work_order_id, wip_records.current_operation_id AS wip_records_current_operation_id, wip_records.current_equipment_id AS wip_records_current_equipment_id, wip_records.quantity AS wip_records_quantity, wip_records.good_quantity AS wip_records_good_quantity, wip_records.scrap_quantity AS wip_records_scrap_quantity, wip_records.rework_quantity AS wip_records_rework_quantity, wip_records.status AS wip_records_status, wip_records.queue_entry_time AS wip_records_queue_entry_time, wip_records.process_start_time AS wip_records_process_start_time, wip_records.process_end_time AS wip_records_process_end_time, wip_records.plant AS wip_records_plant, wip_records.work_center AS wip_records_work_center, wip_records.storage_location AS wip_records_storage_location, wip_records.batch_number AS wip_records_batch_number, wip_records.serial_numbers AS wip_records_serial_numbers, wip_records.created_at AS wip_records_created_at, wip_records.updated_at AS wip_records_updated_at
# FROM wip_records
# WHERE wip_records.wip_lot_number = %(wip_lot_number_1)s
#  LIMIT %(param_1)s
# 2025-09-03 09:12:08,860 INFO sqlalchemy.engine.Engine [cached since 2663s ago] {'wip_lot_number_1': 'LOT-001', 'param_1': 1}
# 2025-09-03 09:12:08,979 INFO sqlalchemy.engine.Engine SELECT work_orders.id AS work_orders_id, work_orders.work_order_number AS work_orders_work_order_number, work_orders.product_id AS work_orders_product_id, work_orders.route_id AS work_orders_route_id, work_orders.order_quantity AS work_orders_order_quantity, work_orders.completed_quantity AS work_orders_completed_quantity, work_orders.scrapped_quantity AS work_orders_scrapped_quantity, work_orders.priority AS work_orders_priority, work_orders.planned_start_date AS work_orders_planned_start_date, work_orders.planned_end_date AS work_orders_planned_end_date, work_orders.actual_start_date AS work_orders_actual_start_date, work_orders.actual_end_date AS work_orders_actual_end_date, work_orders.due_date AS work_orders_due_date, work_orders.status AS work_orders_status, work_orders.parent_work_order_id AS work_orders_parent_work_order_id, work_orders.sales_order_number AS work_orders_sales_order_number, work_orders.customer_name AS work_orders_customer_name, work_orders.estimated_cost AS work_orders_estimated_cost, work_orders.actual_cost AS work_orders_actual_cost, work_orders.notes AS work_orders_notes, work_orders.created_by AS work_orders_created_by, work_orders.released_by AS work_orders_released_by, work_orders.created_at AS work_orders_created_at, work_orders.updated_at AS work_orders_updated_at
# FROM work_orders
# WHERE work_orders.id = %(pk_1)s
# 2025-09-03 09:12:08,983 INFO sqlalchemy.engine.Engine [cached since 2663s ago] {'pk_1': 1}
# 2025-09-03 09:12:08,995 INFO sqlalchemy.engine.Engine SELECT operations.id AS operations_id, operations.operation_number AS operations_operation_number, operations.operation_code AS operations_operation_code, operations.name AS operations_name, operations.description AS operations_description, operations.operation_type AS operations_operation_type, operations.status AS operations_status, operations.setup_time_minutes AS operations_setup_time_minutes, operations.cycle_time_minutes AS operations_cycle_time_minutes, operations.labor_time_minutes AS operations_labor_time_minutes, operations.machine_time_minutes AS operations_machine_time_minutes, operations.operators_required AS operations_operators_required, operations.skill_level_required AS operations_skill_level_required, operations.inspection_required AS operations_inspection_required, operations.inspection_frequency AS operations_inspection_frequency, operations.scrap_rate AS operations_scrap_rate, operations.rework_rate AS operations_rework_rate, operations.work_instructions AS operations_work_instructions, operations.setup_instructions AS operations_setup_instructions, operations.quality_instructions AS operations_quality_instructions, operations.sequence_id AS operations_sequence_id, operations.created_at AS operations_created_at, operations.updated_at AS operations_updated_at
# FROM operations
# WHERE operations.id = %(pk_1)s
# 2025-09-03 09:12:08,996 INFO sqlalchemy.engine.Engine [cached since 2663s ago] {'pk_1': 1}
# 2025-09-03 09:12:09,011 INFO sqlalchemy.engine.Engine SELECT equipment.id AS equipment_id, equipment.code AS equipment_code, equipment.name AS equipment_name, equipment.description AS equipment_description, equipment.equipment_group AS equipment_equipment_group, equipment.capacity_per_hour AS equipment_capacity_per_hour, equipment.efficiency AS equipment_efficiency, equipment.oee_target AS equipment_oee_target, equipment.status AS equipment_status, equipment.last_maintenance_date AS equipment_last_maintenance_date, equipment.next_maintenance_date AS equipment_next_maintenance_date, equipment.mtbf_hours AS equipment_mtbf_hours, equipment.mttr_hours AS equipment_mttr_hours, equipment.plant AS equipment_plant, equipment.department AS equipment_department, equipment.work_center AS equipment_work_center, equipment.created_at AS equipment_created_at, equipment.updated_at AS equipment_updated_at
# FROM equipment
# WHERE equipment.id = %(pk_1)s
# 2025-09-03 09:12:09,012 INFO sqlalchemy.engine.Engine [cached since 2663s ago] {'pk_1': 1}
# 2025-09-03 09:12:09,091 INFO sqlalchemy.engine.Engine UPDATE wip_records SET current_operation_id=%(current_operation_id)s, status=%(status)s, queue_entry_time=%(queue_entry_time)s, updated_at=%(updated_at)s WHERE wip_records.id = %(wip_records_id)s
# 2025-09-03 09:12:09,116 INFO sqlalchemy.engine.Engine [cached since 2641s ago] {'current_operation_id': 2, 'status': 'QUEUE', 'queue_entry_time': datetime.datetime(2025, 9, 3, 1, 27, 9, 82707), 'updated_at': datetime.datetime(2025, 9, 3, 1, 12, 9, 90764), 'wip_records_id': 1}
# 2025-09-03 09:12:09,157 INFO sqlalchemy.engine.Engine INSERT INTO wip_history (wip_record_id, wip_lot_number, work_order_number, event_type, event_timestamp, operation_id, operation_code, equipment_id, equipment_code, plant, work_center, quantity, good_quantity, scrap_quantity, rework_quantity, previous ... 2269 characters truncated ... , p28, p29, p30, sen_counter) ORDER BY sen_counter RETURNING wip_history.id, wip_history.id AS id__1
# 2025-09-03 09:12:09,159 INFO sqlalchemy.engine.Engine [cached since 9732s ago (insertmanyvalues) 1/1 (ordered)] {'measurement_data__0': 'null', 'quantity__0': Decimal('50.00'), 'rework_quantity__0': Decimal('0.00'), 'defect_codes__0': 'null', 'cycle_time_minutes__0': None, 'reason_code__0': None, 'plant__0': 'Plant 1', 'work_center__0': 'WC-001', 'event_type__0': 'move_start', 'operation_code__0': 'OP-001', 'work_order_number__0': 'WO-2024-001', 'equipment_id__0': 1, 'good_quantity__0': Decimal('95.00'), 'queue_time_minutes__0': None, 'equipment_code__0': 'CNC-001', 'wip_lot_number__0': 'LOT-001', 'notes__0': None, 'terminal_id__0': None, 'wip_record_id__0': 1, 'quality_check_result__0': None, 'move_time_minutes__0': None, 'created_by__0': 'system', 'scrap_quantity__0': Decimal('5.00'), 'shift__0': None, 'operator_id__0': None, 'event_timestamp__0': datetime.datetime(2025, 9, 3, 1, 12, 8, 976030), 'operation_id__0': 1, 'operator_name__0': None, 'setup_time_minutes__0': None, 'new_status__0': 'completed', 'previous_status__0': None, 'measurement_data__1': 'null', 'quantity__1': Decimal('50.00'), 'rework_quantity__1': Decimal('0.00'), 'defect_codes__1': 'null', 'cycle_time_minutes__1': None, 'reason_code__1': None, 'plant__1': 'Plant 1', 'work_center__1': 'WC-001', 'event_type__1': 'move_complete', 'operation_code__1': 'OP-001', 'work_order_number__1': 'WO-2024-001', 'equipment_id__1': 1, 'good_quantity__1': Decimal('95.00'), 'queue_time_minutes__1': None, 'equipment_code__1': 'CNC-001', 'wip_lot_number__1': 'LOT-001', 'notes__1': None, 'terminal_id__1': None, 'wip_record_id__1': 1, 'quality_check_result__1': None, 'move_time_minutes__1': None, 'created_by__1': 'system', 'scrap_quantity__1': Decimal('5.00'), 'shift__1': None, 'operator_id__1': None, 'event_timestamp__1': datetime.datetime(2025, 9, 3, 1, 27, 9, 82707), 'operation_id__1': 2, 'operator_name__1': None, 'setup_time_minutes__1': None, 'new_status__1': 'queue', 'previous_status__1': None}
# 2025-09-03 09:12:09,218 INFO sqlalchemy.engine.Engine COMMIT
# True

# %%
# Record quality check
tracker.record_quality_check(session, "LOT-001", passed=True, 
                                measurements={'dimension': 10.05}, 
                                inspector_id="QC01")
# Out:
# 2025-09-03 09:44:46,847 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-03 09:44:46,849 INFO sqlalchemy.engine.Engine SELECT wip_records.id AS wip_records_id, wip_records.wip_lot_number AS wip_records_wip_lot_number, wip_records.work_order_id AS wip_records_work_order_id, wip_records.current_operation_id AS wip_records_current_operation_id, wip_records.current_equipment_id AS wip_records_current_equipment_id, wip_records.quantity AS wip_records_quantity, wip_records.good_quantity AS wip_records_good_quantity, wip_records.scrap_quantity AS wip_records_scrap_quantity, wip_records.rework_quantity AS wip_records_rework_quantity, wip_records.status AS wip_records_status, wip_records.queue_entry_time AS wip_records_queue_entry_time, wip_records.process_start_time AS wip_records_process_start_time, wip_records.process_end_time AS wip_records_process_end_time, wip_records.plant AS wip_records_plant, wip_records.work_center AS wip_records_work_center, wip_records.storage_location AS wip_records_storage_location, wip_records.batch_number AS wip_records_batch_number, wip_records.serial_numbers AS wip_records_serial_numbers, wip_records.created_at AS wip_records_created_at, wip_records.updated_at AS wip_records_updated_at
# FROM wip_records
# WHERE wip_records.wip_lot_number = %(wip_lot_number_1)s
#  LIMIT %(param_1)s
# 2025-09-03 09:44:46,849 INFO sqlalchemy.engine.Engine [cached since 4621s ago] {'wip_lot_number_1': 'LOT-001', 'param_1': 1}
# 2025-09-03 09:44:46,862 INFO sqlalchemy.engine.Engine SELECT work_orders.id AS work_orders_id, work_orders.work_order_number AS work_orders_work_order_number, work_orders.product_id AS work_orders_product_id, work_orders.route_id AS work_orders_route_id, work_orders.order_quantity AS work_orders_order_quantity, work_orders.completed_quantity AS work_orders_completed_quantity, work_orders.scrapped_quantity AS work_orders_scrapped_quantity, work_orders.priority AS work_orders_priority, work_orders.planned_start_date AS work_orders_planned_start_date, work_orders.planned_end_date AS work_orders_planned_end_date, work_orders.actual_start_date AS work_orders_actual_start_date, work_orders.actual_end_date AS work_orders_actual_end_date, work_orders.due_date AS work_orders_due_date, work_orders.status AS work_orders_status, work_orders.parent_work_order_id AS work_orders_parent_work_order_id, work_orders.sales_order_number AS work_orders_sales_order_number, work_orders.customer_name AS work_orders_customer_name, work_orders.estimated_cost AS work_orders_estimated_cost, work_orders.actual_cost AS work_orders_actual_cost, work_orders.notes AS work_orders_notes, work_orders.created_by AS work_orders_created_by, work_orders.released_by AS work_orders_released_by, work_orders.created_at AS work_orders_created_at, work_orders.updated_at AS work_orders_updated_at
# FROM work_orders
# WHERE work_orders.id = %(pk_1)s
# 2025-09-03 09:44:46,863 INFO sqlalchemy.engine.Engine [cached since 4621s ago] {'pk_1': 1}
# 2025-09-03 09:44:46,867 INFO sqlalchemy.engine.Engine SELECT operations.id AS operations_id, operations.operation_number AS operations_operation_number, operations.operation_code AS operations_operation_code, operations.name AS operations_name, operations.description AS operations_description, operations.operation_type AS operations_operation_type, operations.status AS operations_status, operations.setup_time_minutes AS operations_setup_time_minutes, operations.cycle_time_minutes AS operations_cycle_time_minutes, operations.labor_time_minutes AS operations_labor_time_minutes, operations.machine_time_minutes AS operations_machine_time_minutes, operations.operators_required AS operations_operators_required, operations.skill_level_required AS operations_skill_level_required, operations.inspection_required AS operations_inspection_required, operations.inspection_frequency AS operations_inspection_frequency, operations.scrap_rate AS operations_scrap_rate, operations.rework_rate AS operations_rework_rate, operations.work_instructions AS operations_work_instructions, operations.setup_instructions AS operations_setup_instructions, operations.quality_instructions AS operations_quality_instructions, operations.sequence_id AS operations_sequence_id, operations.created_at AS operations_created_at, operations.updated_at AS operations_updated_at
# FROM operations
# WHERE operations.id = %(pk_1)s
# 2025-09-03 09:44:46,868 INFO sqlalchemy.engine.Engine [cached since 4621s ago] {'pk_1': 2}
# 2025-09-03 09:44:46,873 INFO sqlalchemy.engine.Engine SELECT equipment.id AS equipment_id, equipment.code AS equipment_code, equipment.name AS equipment_name, equipment.description AS equipment_description, equipment.equipment_group AS equipment_equipment_group, equipment.capacity_per_hour AS equipment_capacity_per_hour, equipment.efficiency AS equipment_efficiency, equipment.oee_target AS equipment_oee_target, equipment.status AS equipment_status, equipment.last_maintenance_date AS equipment_last_maintenance_date, equipment.next_maintenance_date AS equipment_next_maintenance_date, equipment.mtbf_hours AS equipment_mtbf_hours, equipment.mttr_hours AS equipment_mttr_hours, equipment.plant AS equipment_plant, equipment.department AS equipment_department, equipment.work_center AS equipment_work_center, equipment.created_at AS equipment_created_at, equipment.updated_at AS equipment_updated_at
# FROM equipment
# WHERE equipment.id = %(pk_1)s
# 2025-09-03 09:44:46,874 INFO sqlalchemy.engine.Engine [cached since 4621s ago] {'pk_1': 1}
# 2025-09-03 09:44:46,894 INFO sqlalchemy.engine.Engine INSERT INTO wip_history (wip_record_id, wip_lot_number, work_order_number, event_type, event_timestamp, operation_id, operation_code, equipment_id, equipment_code, plant, work_center, quantity, good_quantity, scrap_quantity, rework_quantity, previous_status, new_status, cycle_time_minutes, setup_time_minutes, queue_time_minutes, move_time_minutes, operator_id, operator_name, shift, quality_check_result, defect_codes, measurement_data, notes, reason_code, created_by, terminal_id) VALUES (%(wip_record_id)s, %(wip_lot_number)s, %(work_order_number)s, %(event_type)s, %(event_timestamp)s, %(operation_id)s, %(operation_code)s, %(equipment_id)s, %(equipment_code)s, %(plant)s, %(work_center)s, %(quantity)s, %(good_quantity)s, %(scrap_quantity)s, %(rework_quantity)s, %(previous_status)s, %(new_status)s, %(cycle_time_minutes)s, %(setup_time_minutes)s, %(queue_time_minutes)s, %(move_time_minutes)s, %(operator_id)s, %(operator_name)s, %(shift)s, %(quality_check_result)s, %(defect_codes)s::JSON, %(measurement_data)s::JSON, %(notes)s, %(reason_code)s, %(created_by)s, %(terminal_id)s) RETURNING wip_history.id
# 2025-09-03 09:44:46,894 INFO sqlalchemy.engine.Engine [cached since 4621s ago] {'wip_record_id': 1, 'wip_lot_number': 'LOT-001', 'work_order_number': 'WO-2024-001', 'event_type': 'inspection_pass', 'event_timestamp': datetime.datetime(2025, 9, 3, 1, 44, 46, 861809), 'operation_id': 2, 'operation_code': 'OP-002', 'equipment_id': 1, 'equipment_code': 'CNC-001', 'plant': 'Plant 1', 'work_center': 'WC-001', 'quantity': Decimal('50.00'), 'good_quantity': Decimal('45.00'), 'scrap_quantity': Decimal('10.00'), 'rework_quantity': Decimal('0.00'), 'previous_status': None, 'new_status': 'completed', 'cycle_time_minutes': None, 'setup_time_minutes': None, 'queue_time_minutes': None, 'move_time_minutes': None, 'operator_id': 'QC01', 'operator_name': None, 'shift': None, 'quality_check_result': 'pass', 'defect_codes': 'null', 'measurement_data': '{"dimension": 10.05}', 'notes': None, 'reason_code': None, 'created_by': 'system', 'terminal_id': None}
# 2025-09-03 09:44:46,908 INFO sqlalchemy.engine.Engine COMMIT
# True

# %%
# Get analytics
analytics = WIPAnalytics()

# Get lot timeline
timeline = analytics.get_lot_timeline(session, "LOT-001")
print("Lot Timeline:", json.dumps(timeline, indent=2, default=str))

# Get operation metrics
metrics = analytics.calculate_operation_metrics(
    session, 
    operation_id=1,
    start_date=datetime.utcnow() - timedelta(days=7),
    end_date=datetime.utcnow()
)
print("Operation Metrics:", json.dumps(metrics, indent=2))

# Get WIP status
wip_status = analytics.get_current_wip_status(session)
print("Current WIP Status:", json.dumps(wip_status, indent=2))

print("\nWIP History tracking system created successfully!")
print("\nExample SQL queries saved to: wip_history_queries.sql")

# Save queries to file
with open('wip_history_queries.sql', 'w') as f:
    f.write(example_queries())
# Out:
# 2025-09-03 09:44:51,556 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-03 09:44:51,557 INFO sqlalchemy.engine.Engine SELECT wip_history.id AS wip_history_id, wip_history.wip_record_id AS wip_history_wip_record_id, wip_history.wip_lot_number AS wip_history_wip_lot_number, wip_history.work_order_number AS wip_history_work_order_number, wip_history.event_type AS wip_history_event_type, wip_history.event_timestamp AS wip_history_event_timestamp, wip_history.operation_id AS wip_history_operation_id, wip_history.operation_code AS wip_history_operation_code, wip_history.equipment_id AS wip_history_equipment_id, wip_history.equipment_code AS wip_history_equipment_code, wip_history.plant AS wip_history_plant, wip_history.work_center AS wip_history_work_center, wip_history.quantity AS wip_history_quantity, wip_history.good_quantity AS wip_history_good_quantity, wip_history.scrap_quantity AS wip_history_scrap_quantity, wip_history.rework_quantity AS wip_history_rework_quantity, wip_history.previous_status AS wip_history_previous_status, wip_history.new_status AS wip_history_new_status, wip_history.cycle_time_minutes AS wip_history_cycle_time_minutes, wip_history.setup_time_minutes AS wip_history_setup_time_minutes, wip_history.queue_time_minutes AS wip_history_queue_time_minutes, wip_history.move_time_minutes AS wip_history_move_time_minutes, wip_history.operator_id AS wip_history_operator_id, wip_history.operator_name AS wip_history_operator_name, wip_history.shift AS wip_history_shift, wip_history.quality_check_result AS wip_history_quality_check_result, wip_history.defect_codes AS wip_history_defect_codes, wip_history.measurement_data AS wip_history_measurement_data, wip_history.notes AS wip_history_notes, wip_history.reason_code AS wip_history_reason_code, wip_history.created_by AS wip_history_created_by, wip_history.terminal_id AS wip_history_terminal_id
# FROM wip_history
# WHERE wip_history.wip_lot_number = %(wip_lot_number_1)s ORDER BY wip_history.event_timestamp
# 2025-09-03 09:44:51,558 INFO sqlalchemy.engine.Engine [cached since 1873s ago] {'wip_lot_number_1': 'LOT-001'}
# Lot Timeline: [
#   {
#     "timestamp": "2025-09-02 08:54:17.476698",
#     "event": "process_start",
#     "operation": "OP-001",
#     "equipment": "CNC-001",
#     "status": "in_process",
#     "quantity": 50.0,
#     "good_quantity": null,
#     "operator": "OP001",
#     "notes": null
#   },
#   {
#     "timestamp": "2025-09-02 08:54:33.256562",
#     "event": "process_complete",
#     "operation": "OP-001",
#     "equipment": "CNC-001",
#     "status": "completed",
#     "quantity": 50.0,
#     "good_quantity": 95.0,
#     "operator": "OP001",
#     "notes": null
#   },
#   {
#     "timestamp": "2025-09-03 01:12:08.976030",
#     "event": "move_start",
#     "operation": "OP-001",
#     "equipment": "CNC-001",
#     "status": "completed",
#     "quantity": 50.0,
#     "good_quantity": 95.0,
#     "operator": null,
#     "notes": null
#   },
#   {
#     "timestamp": "2025-09-03 01:13:28.606128",
#     "event": "inspection_pass",
#     "operation": "OP-002",
#     "equipment": "CNC-001",
#     "status": "queue",
#     "quantity": 50.0,
#     "good_quantity": 95.0,
#     "operator": "QC01",
#     "notes": null
#   },
#   {
#     "timestamp": "2025-09-03 01:27:09.082707",
#     "event": "move_complete",
#     "operation": "OP-001",
#     "equipment": "CNC-001",
#     "status": "queue",
#     "quantity": 50.0,
#     "good_quantity": 95.0,
#     "operator": null,
#     "notes": null
#   },
#   {
#     "timestamp": "2025-09-03 01:44:13.134818",
#     "event": "process_complete",
#     "operation": "OP-002",
#     "equipment": "CNC-001",
#     "status": "completed",
#     "quantity": 50.0,
#     "good_quantity": 45.0,
#     "operator": "OP001",
#     "notes": null
#   },
#   {
#     "timestamp": "2025-09-03 01:44:46.861809",
#     "event": "inspection_pass",
#     "operation": "OP-002",
#     "equipment": "CNC-001",
#     "status": "completed",
#     "quantity": 50.0,
#     "good_quantity": 45.0,
#     "operator": "QC01",
#     "notes": null
#   }
# ]
# 2025-09-03 09:44:51,604 INFO sqlalchemy.engine.Engine SELECT wip_history.id AS wip_history_id, wip_history.wip_record_id AS wip_history_wip_record_id, wip_history.wip_lot_number AS wip_history_wip_lot_number, wip_history.work_order_number AS wip_history_work_order_number, wip_history.event_type AS wip_history_event_type, wip_history.event_timestamp AS wip_history_event_timestamp, wip_history.operation_id AS wip_history_operation_id, wip_history.operation_code AS wip_history_operation_code, wip_history.equipment_id AS wip_history_equipment_id, wip_history.equipment_code AS wip_history_equipment_code, wip_history.plant AS wip_history_plant, wip_history.work_center AS wip_history_work_center, wip_history.quantity AS wip_history_quantity, wip_history.good_quantity AS wip_history_good_quantity, wip_history.scrap_quantity AS wip_history_scrap_quantity, wip_history.rework_quantity AS wip_history_rework_quantity, wip_history.previous_status AS wip_history_previous_status, wip_history.new_status AS wip_history_new_status, wip_history.cycle_time_minutes AS wip_history_cycle_time_minutes, wip_history.setup_time_minutes AS wip_history_setup_time_minutes, wip_history.queue_time_minutes AS wip_history_queue_time_minutes, wip_history.move_time_minutes AS wip_history_move_time_minutes, wip_history.operator_id AS wip_history_operator_id, wip_history.operator_name AS wip_history_operator_name, wip_history.shift AS wip_history_shift, wip_history.quality_check_result AS wip_history_quality_check_result, wip_history.defect_codes AS wip_history_defect_codes, wip_history.measurement_data AS wip_history_measurement_data, wip_history.notes AS wip_history_notes, wip_history.reason_code AS wip_history_reason_code, wip_history.created_by AS wip_history_created_by, wip_history.terminal_id AS wip_history_terminal_id
# FROM wip_history
# WHERE wip_history.operation_id = %(operation_id_1)s AND wip_history.event_type = %(event_type_1)s AND wip_history.event_timestamp BETWEEN %(event_timestamp_1)s AND %(event_timestamp_2)s
# 2025-09-03 09:44:51,605 INFO sqlalchemy.engine.Engine [cached since 1873s ago] {'operation_id_1': 1, 'event_type_1': 'process_complete', 'event_timestamp_1': datetime.datetime(2025, 8, 27, 1, 44, 51, 604130), 'event_timestamp_2': datetime.datetime(2025, 9, 3, 1, 44, 51, 604159)}
# Operation Metrics: {
#   "total_lots_processed": 1,
#   "total_quantity_produced": 95.0,
#   "total_scrap": 5.0,
#   "average_cycle_time": 0,
#   "min_cycle_time": 0,
#   "max_cycle_time": 0,
#   "first_pass_yield": 95.0,
#   "throughput_per_hour": 0
# }
# 2025-09-03 09:44:51,611 INFO sqlalchemy.engine.Engine SELECT wip_history.id AS wip_history_id, wip_history.wip_record_id AS wip_history_wip_record_id, wip_history.wip_lot_number AS wip_history_wip_lot_number, wip_history.work_order_number AS wip_history_work_order_number, wip_history.event_type AS wip_history_event_type, wip_history.event_timestamp AS wip_history_event_timestamp, wip_history.operation_id AS wip_history_operation_id, wip_history.operation_code AS wip_history_operation_code, wip_history.equipment_id AS wip_history_equipment_id, wip_history.equipment_code AS wip_history_equipment_code, wip_history.plant AS wip_history_plant, wip_history.work_center AS wip_history_work_center, wip_history.quantity AS wip_history_quantity, wip_history.good_quantity AS wip_history_good_quantity, wip_history.scrap_quantity AS wip_history_scrap_quantity, wip_history.rework_quantity AS wip_history_rework_quantity, wip_history.previous_status AS wip_history_previous_status, wip_history.new_status AS wip_history_new_status, wip_history.cycle_time_minutes AS wip_history_cycle_time_minutes, wip_history.setup_time_minutes AS wip_history_setup_time_minutes, wip_history.queue_time_minutes AS wip_history_queue_time_minutes, wip_history.move_time_minutes AS wip_history_move_time_minutes, wip_history.operator_id AS wip_history_operator_id, wip_history.operator_name AS wip_history_operator_name, wip_history.shift AS wip_history_shift, wip_history.quality_check_result AS wip_history_quality_check_result, wip_history.defect_codes AS wip_history_defect_codes, wip_history.measurement_data AS wip_history_measurement_data, wip_history.notes AS wip_history_notes, wip_history.reason_code AS wip_history_reason_code, wip_history.created_by AS wip_history_created_by, wip_history.terminal_id AS wip_history_terminal_id
# FROM wip_history JOIN (SELECT wip_history.wip_lot_number AS wip_lot_number, max(wip_history.event_timestamp) AS latest_timestamp
# FROM wip_history GROUP BY wip_history.wip_lot_number) AS anon_1 ON wip_history.wip_lot_number = anon_1.wip_lot_number AND wip_history.event_timestamp = anon_1.latest_timestamp
# 2025-09-03 09:44:51,611 INFO sqlalchemy.engine.Engine [cached since 1873s ago] {}
# Current WIP Status: {
#   "total_lots": 13,
#   "by_status": {
#     "queue": 12,
#     "completed": 1
#   },
#   "by_operation": {
#     "OP-002": 1
#   },
#   "by_work_center": {
#     "WC-001": 1
#   }
# }
#
# WIP History tracking system created successfully!
#
# Example SQL queries saved to: wip_history_queries.sql
# /var/folders/bd/8_cnk3jx3356xd810qw_vv6r0000gn/T/ipykernel_92755/1306041508.py:12: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start_date=datetime.utcnow() - timedelta(days=7),
# /var/folders/bd/8_cnk3jx3356xd810qw_vv6r0000gn/T/ipykernel_92755/1306041508.py:13: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   end_date=datetime.utcnow()

# %%
from manufacturing.wip_data_corrector import WIPDataCorrector
import json
# 1. First, generate a report to understand the issue
corrector = WIPDataCorrector()
report = corrector.create_correction_report(session, "LOT-001")
print("Correction Report:")
print(json.dumps(report, indent=2, default=str))

# 2. Apply specific correction for LOT-001
# Since quantity is 50, good_quantity should be at most 50
corrections = corrector.correct_good_quantity(
    session, 
    wip_lot_number="LOT-001",
    correct_good_qty=45,  # The actual correct value
    create_audit=True
)

print(f"Applied {len(corrections)} corrections:")
for correction in corrections:
    print(f"  Changed good_qty from {correction['old_good_qty']} to {correction['new_good_qty']}")

# 3. Verify the correction
analytics = WIPAnalytics()
timeline_after = analytics.get_lot_timeline(session, "LOT-001")
print("\nTimeline after correction:")
print(json.dumps(timeline_after, indent=2, default=str))
# Out:
# 2025-09-03 11:03:49,474 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-03 11:03:49,476 INFO sqlalchemy.engine.Engine SELECT wip_history.id AS wip_history_id, wip_history.wip_record_id AS wip_history_wip_record_id, wip_history.wip_lot_number AS wip_history_wip_lot_number, wip_history.work_order_number AS wip_history_work_order_number, wip_history.event_type AS wip_history_event_type, wip_history.event_timestamp AS wip_history_event_timestamp, wip_history.operation_id AS wip_history_operation_id, wip_history.operation_code AS wip_history_operation_code, wip_history.equipment_id AS wip_history_equipment_id, wip_history.equipment_code AS wip_history_equipment_code, wip_history.plant AS wip_history_plant, wip_history.work_center AS wip_history_work_center, wip_history.quantity AS wip_history_quantity, wip_history.good_quantity AS wip_history_good_quantity, wip_history.scrap_quantity AS wip_history_scrap_quantity, wip_history.rework_quantity AS wip_history_rework_quantity, wip_history.previous_status AS wip_history_previous_status, wip_history.new_status AS wip_history_new_status, wip_history.cycle_time_minutes AS wip_history_cycle_time_minutes, wip_history.setup_time_minutes AS wip_history_setup_time_minutes, wip_history.queue_time_minutes AS wip_history_queue_time_minutes, wip_history.move_time_minutes AS wip_history_move_time_minutes, wip_history.operator_id AS wip_history_operator_id, wip_history.operator_name AS wip_history_operator_name, wip_history.shift AS wip_history_shift, wip_history.quality_check_result AS wip_history_quality_check_result, wip_history.defect_codes AS wip_history_defect_codes, wip_history.measurement_data AS wip_history_measurement_data, wip_history.notes AS wip_history_notes, wip_history.reason_code AS wip_history_reason_code, wip_history.created_by AS wip_history_created_by, wip_history.terminal_id AS wip_history_terminal_id
# FROM wip_history
# WHERE wip_history.wip_lot_number = %(wip_lot_number_1)s ORDER BY wip_history.event_timestamp
# 2025-09-03 11:03:49,478 INFO sqlalchemy.engine.Engine [cached since 79.32s ago] {'wip_lot_number_1': 'LOT-001'}
# Correction Report:
# {
#   "lot_number": "LOT-001",
#   "issues_found": [],
#   "suggested_corrections": []
# }
# 2025-09-03 11:03:49,526 INFO sqlalchemy.engine.Engine SELECT wip_history.id AS wip_history_id, wip_history.wip_record_id AS wip_history_wip_record_id, wip_history.wip_lot_number AS wip_history_wip_lot_number, wip_history.work_order_number AS wip_history_work_order_number, wip_history.event_type AS wip_history_event_type, wip_history.event_timestamp AS wip_history_event_timestamp, wip_history.operation_id AS wip_history_operation_id, wip_history.operation_code AS wip_history_operation_code, wip_history.equipment_id AS wip_history_equipment_id, wip_history.equipment_code AS wip_history_equipment_code, wip_history.plant AS wip_history_plant, wip_history.work_center AS wip_history_work_center, wip_history.quantity AS wip_history_quantity, wip_history.good_quantity AS wip_history_good_quantity, wip_history.scrap_quantity AS wip_history_scrap_quantity, wip_history.rework_quantity AS wip_history_rework_quantity, wip_history.previous_status AS wip_history_previous_status, wip_history.new_status AS wip_history_new_status, wip_history.cycle_time_minutes AS wip_history_cycle_time_minutes, wip_history.setup_time_minutes AS wip_history_setup_time_minutes, wip_history.queue_time_minutes AS wip_history_queue_time_minutes, wip_history.move_time_minutes AS wip_history_move_time_minutes, wip_history.operator_id AS wip_history_operator_id, wip_history.operator_name AS wip_history_operator_name, wip_history.shift AS wip_history_shift, wip_history.quality_check_result AS wip_history_quality_check_result, wip_history.defect_codes AS wip_history_defect_codes, wip_history.measurement_data AS wip_history_measurement_data, wip_history.notes AS wip_history_notes, wip_history.reason_code AS wip_history_reason_code, wip_history.created_by AS wip_history_created_by, wip_history.terminal_id AS wip_history_terminal_id
# FROM wip_history
# WHERE wip_history.wip_lot_number = %(wip_lot_number_1)s
# 2025-09-03 11:03:49,527 INFO sqlalchemy.engine.Engine [cached since 79.32s ago] {'wip_lot_number_1': 'LOT-001'}
# 2025-09-03 11:03:49,530 INFO sqlalchemy.engine.Engine COMMIT
# Applied 0 corrections:
# 2025-09-03 11:03:49,534 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-03 11:03:49,534 INFO sqlalchemy.engine.Engine SELECT wip_history.id AS wip_history_id, wip_history.wip_record_id AS wip_history_wip_record_id, wip_history.wip_lot_number AS wip_history_wip_lot_number, wip_history.work_order_number AS wip_history_work_order_number, wip_history.event_type AS wip_history_event_type, wip_history.event_timestamp AS wip_history_event_timestamp, wip_history.operation_id AS wip_history_operation_id, wip_history.operation_code AS wip_history_operation_code, wip_history.equipment_id AS wip_history_equipment_id, wip_history.equipment_code AS wip_history_equipment_code, wip_history.plant AS wip_history_plant, wip_history.work_center AS wip_history_work_center, wip_history.quantity AS wip_history_quantity, wip_history.good_quantity AS wip_history_good_quantity, wip_history.scrap_quantity AS wip_history_scrap_quantity, wip_history.rework_quantity AS wip_history_rework_quantity, wip_history.previous_status AS wip_history_previous_status, wip_history.new_status AS wip_history_new_status, wip_history.cycle_time_minutes AS wip_history_cycle_time_minutes, wip_history.setup_time_minutes AS wip_history_setup_time_minutes, wip_history.queue_time_minutes AS wip_history_queue_time_minutes, wip_history.move_time_minutes AS wip_history_move_time_minutes, wip_history.operator_id AS wip_history_operator_id, wip_history.operator_name AS wip_history_operator_name, wip_history.shift AS wip_history_shift, wip_history.quality_check_result AS wip_history_quality_check_result, wip_history.defect_codes AS wip_history_defect_codes, wip_history.measurement_data AS wip_history_measurement_data, wip_history.notes AS wip_history_notes, wip_history.reason_code AS wip_history_reason_code, wip_history.created_by AS wip_history_created_by, wip_history.terminal_id AS wip_history_terminal_id
# FROM wip_history
# WHERE wip_history.wip_lot_number = %(wip_lot_number_1)s ORDER BY wip_history.event_timestamp
# 2025-09-03 11:03:49,535 INFO sqlalchemy.engine.Engine [cached since 79.37s ago] {'wip_lot_number_1': 'LOT-001'}
#
# Timeline after correction:
# [
#   {
#     "timestamp": "2025-09-02 08:54:17.476698",
#     "event": "process_start",
#     "operation": "OP-001",
#     "equipment": "CNC-001",
#     "status": "in_process",
#     "quantity": 50.0,
#     "good_quantity": null,
#     "operator": "OP001",
#     "notes": null
#   },
#   {
#     "timestamp": "2025-09-02 08:54:33.256562",
#     "event": "process_complete",
#     "operation": "OP-001",
#     "equipment": "CNC-001",
#     "status": "completed",
#     "quantity": 50.0,
#     "good_quantity": 45.0,
#     "operator": "OP001",
#     "notes": null
#   },
#   {
#     "timestamp": "2025-09-03 01:12:08.976030",
#     "event": "move_start",
#     "operation": "OP-001",
#     "equipment": "CNC-001",
#     "status": "completed",
#     "quantity": 50.0,
#     "good_quantity": 45.0,
#     "operator": null,
#     "notes": null
#   },
#   {
#     "timestamp": "2025-09-03 01:13:28.606128",
#     "event": "inspection_pass",
#     "operation": "OP-002",
#     "equipment": "CNC-001",
#     "status": "queue",
#     "quantity": 50.0,
#     "good_quantity": 45.0,
#     "operator": "QC01",
#     "notes": null
#   },
#   {
#     "timestamp": "2025-09-03 01:27:09.082707",
#     "event": "move_complete",
#     "operation": "OP-001",
#     "equipment": "CNC-001",
#     "status": "queue",
#     "quantity": 50.0,
#     "good_quantity": 45.0,
#     "operator": null,
#     "notes": null
#   },
#   {
#     "timestamp": "2025-09-03 01:44:13.134818",
#     "event": "process_complete",
#     "operation": "OP-002",
#     "equipment": "CNC-001",
#     "status": "completed",
#     "quantity": 50.0,
#     "good_quantity": 45.0,
#     "operator": "OP001",
#     "notes": null
#   },
#   {
#     "timestamp": "2025-09-03 01:44:46.861809",
#     "event": "inspection_pass",
#     "operation": "OP-002",
#     "equipment": "CNC-001",
#     "status": "completed",
#     "quantity": 50.0,
#     "good_quantity": 45.0,
#     "operator": "QC01",
#     "notes": null
#   },
#   {
#     "timestamp": "2025-09-03 03:02:30.222062",
#     "event": "data_correction",
#     "operation": "OP-001",
#     "equipment": null,
#     "status": null,
#     "quantity": 50.0,
#     "good_quantity": 45.0,
#     "operator": null,
#     "notes": "Data correction: good_quantity changed from 95.00 to 45"
#   },
#   {
#     "timestamp": "2025-09-03 03:02:30.222211",
#     "event": "data_correction",
#     "operation": "OP-001",
#     "equipment": null,
#     "status": null,
#     "quantity": 50.0,
#     "good_quantity": 45.0,
#     "operator": null,
#     "notes": "Data correction: good_quantity changed from 95.00 to 45"
#   },
#   {
#     "timestamp": "2025-09-03 03:02:30.222274",
#     "event": "data_correction",
#     "operation": "OP-001",
#     "equipment": null,
#     "status": null,
#     "quantity": 50.0,
#     "good_quantity": 45.0,
#     "operator": null,
#     "notes": "Data correction: good_quantity changed from 95.00 to 45"
#   },
#   {
#     "timestamp": "2025-09-03 03:02:30.222320",
#     "event": "data_correction",
#     "operation": "OP-002",
#     "equipment": null,
#     "status": null,
#     "quantity": 50.0,
#     "good_quantity": 45.0,
#     "operator": null,
#     "notes": "Data correction: good_quantity changed from 95.00 to 45"
#   }
# ]
